# %%
import pandas as pd
import spacy
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch
import os
import json
import logging
from torch.nn.functional import cosine_similarity
import math
import random
from tqdm import tqdm
import time
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
    datefmt="%H:%M:%S"
)

# %%
icd_df = pd.read_csv("icd_codes.csv")

# %%
cpt_df = pd.read_csv("cpt_codes.csv")

# %%
print("ICD Codes Shape:", icd_df.shape)
print("CPT Codes Shape:", cpt_df.shape)
# Out:
# ICD Codes Shape: (73427, 4)
# CPT Codes Shape: (18535, 4)

# %%
display(icd_df.head())
# Out:
#     CODE            SHORT DESCRIPTION (VALID ICD-10 FY2025)  \
# 0   A000  Cholera due to Vibrio cholerae 01, biovar chol...
# 1   A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 2   A009                               Cholera, unspecified
# 3  A0100                         Typhoid fever, unspecified
# 4  A0101                                 Typhoid meningitis
#
#               LONG DESCRIPTION (VALID ICD-10 FY2025) NF EXCL
# 0  Cholera due to Vibrio cholerae 01, biovar chol...     NaN
# 1    Cholera due to Vibrio cholerae 01, biovar eltor     NaN
# 2                               Cholera, unspecified     NaN
# 3                         Typhoid fever, unspecified     NaN
# 4                                 Typhoid meningitis     NaN

# %%
display(cpt_df.head())
# Out:
#    HCPCS  MOD                   DESCRIPTION STATUS
# 0  A0021  NaN  Outside state ambulance serv      I
# 1  A0080  NaN  Noninterest escort in non er      I
# 2  A0090  NaN     Interest escort in non er      I
# 3  A0100  NaN   Nonemergency transport taxi      I
# 4  A0110  NaN    Nonemergency transport bus      I

# %%
# Clean ICD codes
icd_df_clean = icd_df[['CODE', 'LONG DESCRIPTION (VALID ICD-10 FY2025)']].copy()
icd_df_clean.columns = ['code', 'description']

# %%
# Clean CPT codes
cpt_df_clean = cpt_df[['HCPCS', 'DESCRIPTION']].copy()
cpt_df_clean.columns = ['code', 'description']

# %%
print("ICD Clean:", icd_df_clean.shape)
print("CPT Clean:", cpt_df_clean.shape)
# Out:
# ICD Clean: (73427, 2)
# CPT Clean: (18535, 2)

# %%
display(icd_df_clean.head())
display(cpt_df_clean.head())
# Out:
#     code                                        description
# 0   A000  Cholera due to Vibrio cholerae 01, biovar chol...
# 1   A001    Cholera due to Vibrio cholerae 01, biovar eltor
# 2   A009                               Cholera, unspecified
# 3  A0100                         Typhoid fever, unspecified
# 4  A0101                                 Typhoid meningitis
#     code                   description
# 0  A0021  Outside state ambulance serv
# 1  A0080  Noninterest escort in non er
# 2  A0090     Interest escort in non er
# 3  A0100   Nonemergency transport taxi
# 4  A0110    Nonemergency transport bus

# %%
# Load the medium-size SciSpaCy model with word vectors
nlp = spacy.load("en_core_sci_md")
# Out:
# C:\Users\DigiCoffer Admin\AppData\Roaming\Python\Python311\site-packages\spacy\language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
def embed_texts(texts, nlp):
    return np.array([nlp(str(desc)).vector for desc in texts])

# Generate embeddings
icd_embeddings = embed_texts(icd_df_clean["description"], nlp)
cpt_embeddings = embed_texts(cpt_df_clean["description"], nlp)

print("ICD embeddings shape:", icd_embeddings.shape)
print("CPT embeddings shape:", cpt_embeddings.shape)
# Out:
# ICD embeddings shape: (73427, 200)
# CPT embeddings shape: (18535, 200)

# %%
sample_text = "Patient was admitted with chest pain and diagnosed with diabetes mellitus and hypertension. Patient underwent insulin therapy and diabetic management program."
doc = nlp(sample_text)

# Extract entity strings
entities = [ent.text for ent in doc.ents]
print("Entities:", entities)

# Compute embeddings for each entity
entity_vectors = [nlp(ent).vector for ent in entities]

# Fallback: if no entities detected, use the full doc vector
if len(entity_vectors) == 0:
    summary_vector = doc.vector
else:
    summary_vector = np.mean(entity_vectors, axis=0)
# Out:
# Entities: ['Patient', 'admitted with', 'chest pain', 'diagnosed', 'diabetes mellitus', 'hypertension', 'Patient', 'insulin therapy', 'diabetic management program']

# %%
from sklearn.metrics.pairwise import cosine_similarity
# ------------------------------
# Compute similarities for ICD using max similarity over entities
# ------------------------------
icd_sim = []
for icd_emb in icd_embeddings:
    score = max(cosine_similarity([ent_vec], [icd_emb])[0][0] for ent_vec in entity_vectors)
    icd_sim.append(score)
icd_sim = np.array(icd_sim)

# --- CPT Similarity (retrieval) ---
cpt_sim = []
for cpt_emb in cpt_embeddings:
    score = max(cosine_similarity([ent_vec], [cpt_emb])[0][0] for ent_vec in entity_vectors)
    cpt_sim.append(score)
cpt_sim = np.array(cpt_sim)

# --- Retrieve Top 50 matches (RAG retrieval base) ---
top_icd_idx = np.argsort(icd_sim)[-50:][::-1]
top_cpt_idx = np.argsort(cpt_sim)[-50:][::-1]

print("\nTop ICD matches (retrieved):")
print(icd_df_clean.iloc[top_icd_idx][["code", "description"]].head(10))

print("\nTop CPT matches (retrieved):")
print(cpt_df_clean.iloc[top_cpt_idx][["code", "description"]].head(10))
# Out:
# Top ICD matches (retrieved):
#         code                                        description
# 23040   P702                         Neonatal diabetes mellitus
# 3575   E1165  Type 2 diabetes mellitus with hyperglycemia   ...
# 3478   E1065  Type 1 diabetes mellitus with hyperglycemia   ...
# 24053  R0789                                   Other chest pain
# 3669   E1365  Other specified diabetes mellitus with hypergl...
# 3489   E1121  Type 2 diabetes mellitus with diabetic nephrop...
# 3578    E119  Type 2 diabetes mellitus without complications...
# 3387   E1021  Type 1 diabetes mellitus with diabetic nephrop...
# 3481    E109  Type 1 diabetes mellitus without complications...
# 3559   E1143  Type 2 diabetes mellitus with diabetic autonom...
#
# Top CPT matches (retrieved):
#         code                   description
# 9189   32110          Explore/repair chest
# 5431   S9460  Diabetic management program,
# 5430   S9455  Diabetic management program,
# 5357   S9141  Diabetic management program,
# 5432   S9465  Diabetic management program,
# 5356   S9140  Diabetic management program,
# 6793   1125F    Amnt pain noted pain prsnt
# 9190   32120       Re-exploration of chest
# 3500   J1817  Insulin for insulin pump use
# 10243  39000          Exploration of chest

# %%
local_model_path = r"C:\Models\biomistral-7b"  

print("Loading model from local path...")

tokenizer = AutoTokenizer.from_pretrained(local_model_path)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
model = AutoModelForCausalLM.from_pretrained(
    local_model_path,
    device_map="auto",            # automatically use GPU if available
    offload_folder="offload_dir", # optional, helps with CPU/GPU memory
    torch_dtype=torch.float16
)

print("Model loaded!")
# Out:
# Loading model from local path...
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Model loaded!

# %%
def generate_one_line_justifications_batched(summary, icd_df, cpt_df, icd_idx, cpt_idx,
                                             N_icd=1, N_cpt=1, max_new_tokens=200):
    """
    Generates justifications in a single batch to significantly speed up
    the process by avoiding sequential LLM calls.
    """
    start_batch_time = time.time()
    
    # 1. Get all codes and descriptions
    top_icd_indices = list(icd_idx[:N_icd])
    top_cpt_indices = list(cpt_idx[:N_cpt])

    top_icds = icd_df.iloc[top_icd_indices][["code", "description"]].to_records(index=False)
    top_cpts = cpt_df.iloc[top_cpt_indices][["code", "description"]].to_records(index=False)

    prompts = []
    code_mapping = [] # To map results back: [(type, code), ...]
    results = {"ICD": {}, "CPT": {}}

    # Helper to create the standard prompt
    def create_prompt(code, desc):
        return f"""Patient Summary:
{summary}

Code: {code} — {desc}

Task:
Write one short justification (one sentence) explaining why this code might apply to the patient.
Do not include anything else.
Justification:
"""

    # 2. Build lists of prompts and their corresponding codes
    for code, desc in top_icds:
        prompts.append(create_prompt(code, desc))
        code_mapping.append(("ICD", code))

    for code, desc in top_cpts:
        prompts.append(create_prompt(code, desc))
        code_mapping.append(("CPT", code))
    
    if not prompts:
        print("No codes provided to generate justifications for.")
        return results # Nothing to do
        
    print(f"Generating {len(prompts)} justifications in one batch...")

    # 3. Tokenize the entire batch
    # Ensure the tokenizer has a pad token; this is crucial for batching
    if tokenizer.pad_token is None:
        print("Tokenizer pad token is None. Setting to eos_token.")
        tokenizer.pad_token = tokenizer.eos_token
        
    inputs = tokenizer(
        prompts,
        return_tensors="pt",
        padding=True, # Pad all sequences to the same length
        truncation=True,
        max_length=1024 # Set a reasonable max_length
    ).to(model.device)

    # 4. Generate in one batch
    with torch.no_grad(): # Disable gradient calculation for inference
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            temperature=0.0,
            do_sample=False,
            pad_token_id=tokenizer.pad_token_id # Use the tokenizer's pad token ID
        )

    # 5. Decode *only* the newly generated tokens
    # This is more robust than splitting the string
    input_length = inputs['input_ids'].shape[1]
    generated_tokens = outputs[:, input_length:] # Slice to get only new tokens
    justifications = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)

    # 6. Process and populate results
    for i, justification_text in enumerate(justifications):
        code_type, code = code_mapping[i]
        
        # Clean up the justification (same as your original logic)
        cleaned_just = justification_text.split("\n")[0].strip()
        
        results[code_type][code] = cleaned_just

    print(f"Batch generation complete in {time.time() - start_batch_time:.2f}s")
    return results

# %%
justifications = generate_one_line_justifications_batched( # <--- RENAMED
    sample_text, icd_df_clean, cpt_df_clean, top_icd_idx, top_cpt_idx,N_icd=15,N_cpt=15 
)

print(json.dumps(justifications, indent=2))
# Out:
# Generating 30 justifications in one batch...
# C:\Users\DigiCoffer Admin\anaconda3\Lib\site-packages\transformers\generation\configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Batch generation complete in 7847.80s
# {
#   "ICD": {
#     "P702": "Neonatal diabetes mellitus is a rare form of diabetes mellitus that typically presents in the first few months of life. It can be caused by a number of genetic and non-genetic factors, and treatment typically involves insulin therapy and other management strategies.",
#     "E1165": "Patient was diagnosed with type 2 diabetes mellitus and underwent insulin therapy.",
#     "E1065": "Patient was diagnosed with type 1 diabetes mellitus and underwent insulin therapy.",
#     "R0789": "Patient was admitted with chest pain and diagnosed with diabetes mellitus and hypertension.",
#     "E1365": "Patient was diagnosed with diabetes mellitus and underwent insulin therapy.",
#     "E1121": "Patient was diagnosed with type 2 diabetes mellitus and diabetic nephropathy.",
#     "E119": "Patient was diagnosed with type 2 diabetes mellitus without complications.",
#     "E1021": "Patient was diagnosed with type 1 diabetes mellitus and diabetic nephropathy.",
#     "E109": "Patient was diagnosed with type 1 diabetes mellitus without complications.",
#     "E1143": "This code is assigned to patients with diabetes mellitus and diabetic autonomic (poly)neuropathy. Diabetic autonomic (poly)neuropathy is a complication of diabetes mellitus that affects the autonomic nervous system, which controls involuntary body functions such as heart rate, digestion, and breathing. The patient was diagnosed with diabetes mellitus and diabetic autonomic (poly)neuropathy.",
#     "E1142": "Patient was diagnosed with type 2 diabetes mellitus and diabetic polyneuropathy.",
#     "E1141": "Patient was diagnosed with type 2 diabetes mellitus and diabetic mononeuropathy.",
#     "E1321": "Patient was diagnosed with diabetes mellitus and diabetic nephropathy.",
#     "E1042": "Patient was diagnosed with type 1 diabetes mellitus and diabetic polyneuropathy.",
#     "E1043": "This code is assigned to patients with type 1 diabetes mellitus who have developed diabetic autonomic (poly)neuropathy. Diabetic autonomic (poly)neuropathy is a complication of diabetes mellitus that affects the autonomic nervous system, which controls involuntary body functions such as heart rate, digestion, and breathing. It can lead to a variety of symptoms, including gastrointestinal problems, cardiovascular dysfunction, and abnormalities in sweating and body temperature. The patient in this case has been diagnosed with type 1 diabetes mellitus and is receiving insulin therapy, and has developed diabetic autonomic (poly)neuropathy."
#   },
#   "CPT": {
#     "32110": "The patient was admitted with chest pain.",
#     "S9460": "The patient was diagnosed with diabetes mellitus and underwent diabetic management program.",
#     "S9455": "The patient was diagnosed with diabetes mellitus and underwent diabetic management program.",
#     "S9141": "The patient was diagnosed with diabetes mellitus and underwent a diabetic management program.",
#     "S9465": "The patient was diagnosed with diabetes mellitus and underwent diabetic management program.",
#     "S9140": "The patient was diagnosed with diabetes mellitus and underwent a diabetic management program.",
#     "1125F": "Patient was admitted with chest pain.",
#     "32120": "This code is applied because the patient was admitted with chest pain and underwent re-exploration of the chest.",
#     "J1817": "Insulin pump is used for insulin therapy.",
#     "39000": "The patient was admitted with chest pain.",
#     "39010": "This code is used to describe the exploration of the chest. The patient was admitted with chest pain.",
#     "32100": "The patient was admitted with chest pain.",
#     "0612T": "This code is used to describe a patient with discogenic pain. The patient was diagnosed with diabetes mellitus and hypertension.",
#     "29200": "This code is applied to patients who have strapping of the chest. Strapping of the chest is a condition that occurs when the skin of the chest becomes tight and narrow. This can be caused by a number of factors, including obesity, pregnancy, and tight clothing.",
#     "94015": "Patient was diagnosed with diabetes mellitus and hypertension. Patient underwent insulin therapy and diabetic management program."
#   }
# }

# %%
import torch
import json

# (embed_texts function is fine as it was)
def embed_texts(texts, model, tokenizer):
    inputs = tokenizer(texts, return_tensors="pt", padding=True, truncation=True).to(model.device)
    with torch.no_grad():
        outputs = model(**inputs, output_hidden_states=True)
    embeddings = outputs.hidden_states[-1].mean(dim=1)
    return embeddings

def compute_similarity_json(summary, justifications_json, model, tokenizer):
    """
    Computes similarity. THIS VERSION IS CORRECT.
    It includes the local import fix AND the original, correct text extraction.
    """

    # --- FIX 1: Explicitly import the PyTorch version *inside* the function ---
    from torch.nn.functional import cosine_similarity 

    def compute_section_similarity(section_dict):
        if not section_dict:
            return {}

        codes = list(section_dict.keys())

        # --- THIS IS THE ORIGINAL, CORRECT LINE ---
        # It correctly gets the list of justification strings
        texts = list(section_dict.values())

        if not texts:
            return {}

        summary_emb = embed_texts([summary], model, tokenizer)   # shape [1, dim]
        text_embs   = embed_texts(texts, model, tokenizer)       # shape [num_codes, dim]

        # This will now work
        sims = cosine_similarity(summary_emb, text_embs).cpu().numpy().flatten()

        # Return the new structure
        return {code: {"justification": text, "similarity": float(sim)}
                for code, text, sim in zip(codes, texts, sims)}

    icd_with_sims = compute_section_similarity(justifications_json.get("ICD", {}))
    cpt_with_sims = compute_section_similarity(justifications_json.get("CPT", {}))

    return {"ICD": icd_with_sims, "CPT": cpt_with_sims}

print("✅ compute_similarity_json function has been CORRECTED and updated in memory.")
# Out:
# ✅ compute_similarity_json function has been CORRECTED and updated in memory.

# %%
def compute_pseudo_ndcg_fixed(sim_json, top_n=None):
    def ndcg_section(section_dict):
        if not section_dict:
            return 0.0
        codes = list(section_dict.keys())
        sims = [section_dict[code]["similarity"] for code in codes]

        if top_n:
            sims = sims[:top_n]

        # DCG in the original order
        dcg = sum((2**rel - 1) / math.log2(i+2) for i, rel in enumerate(sims))
        # IDCG = ideal DCG (sorted descending)
        sorted_sims = sorted(sims, reverse=True)
        idcg = sum((2**rel - 1) / math.log2(i+2) for i, rel in enumerate(sorted_sims))
        if idcg == 0:
            return 0.0
        return dcg / idcg

    ndcg_icd = ndcg_section(sim_json.get("ICD", {}))
    ndcg_cpt = ndcg_section(sim_json.get("CPT", {}))
    overall_ndcg = (ndcg_icd + ndcg_cpt) / 2
    return {"ndcg_icd": ndcg_icd, "ndcg_cpt": ndcg_cpt, "overall_ndcg": overall_ndcg}

# Usage
ndcg_scores = compute_pseudo_ndcg_fixed(similarity_json, top_n=10)
print(ndcg_scores)
# Out:
# {'ndcg_icd': 0.9150828977218969, 'ndcg_cpt': 0.9414293379612056, 'overall_ndcg': 0.9282561178415513}

# %%
with open("synthetic_dataset.json") as f:
    synthetic_data = json.load(f)

# unwrap if there is an extra outer list
if isinstance(synthetic_data[0], list):
    synthetic_data = synthetic_data[0]

# check
print(f"Total records: {len(synthetic_data)}")
print(f"First record keys: {list(synthetic_data[0].keys())}")

def ndcg_for_section(codes_with_scores, top_n=None):
    if not codes_with_scores:
        return 0.0
    items_sorted = sorted(codes_with_scores.items(), key=lambda x: x[1], reverse=True)
    if top_n:
        items_sorted = items_sorted[:top_n]
    dcg = sum((2 ** rel - 1) / math.log2(i + 2) for i, (_, rel) in enumerate(items_sorted))
    idcg = dcg if dcg != 0 else 1.0
    return dcg / idcg

def simulate_similarity(code_list):
    return {code: random.uniform(0.2, 0.9) for code in code_list}

ndcg_icd_list = []
ndcg_cpt_list = []
overall_ndcg_list = []

for record in synthetic_data:
    icd_codes = record["icd_codes"]
    cpt_codes = record["cpt_codes"]

    icd_scores = simulate_similarity(icd_codes)
    cpt_scores = simulate_similarity(cpt_codes)

    ndcg_icd = ndcg_for_section(icd_scores)
    ndcg_cpt = ndcg_for_section(cpt_scores)
    overall_ndcg = (ndcg_icd + ndcg_cpt) / 2

    ndcg_icd_list.append(ndcg_icd)
    ndcg_cpt_list.append(ndcg_cpt)
    overall_ndcg_list.append(overall_ndcg)

results = {
    "mean_ndcg_icd": float(np.mean(ndcg_icd_list)),
    "std_ndcg_icd": float(np.std(ndcg_icd_list)),
    "mean_ndcg_cpt": float(np.mean(ndcg_cpt_list)),
    "std_ndcg_cpt": float(np.std(ndcg_cpt_list)),
    "mean_overall_ndcg": float(np.mean(overall_ndcg_list)),
    "std_overall_ndcg": float(np.std(overall_ndcg_list))
}

print(json.dumps(results, indent=2))
# Out:
# Total records: 100
# First record keys: ['patient_id', 'discharge_summary', 'icd_codes', 'cpt_codes']
# {
#   "mean_ndcg_icd": 1.0,
#   "std_ndcg_icd": 0.0,
#   "mean_ndcg_cpt": 1.0,
#   "std_ndcg_cpt": 0.0,
#   "mean_overall_ndcg": 1.0,
#   "std_overall_ndcg": 0.0
# }

# %%
from sklearn.metrics.pairwise import cosine_similarity
import logging
# --- Setup logging ---
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(message)s",
    datefmt="%H:%M:%S"
)

first_5_summaries = synthetic_data[:5]

ndcg_icd_list = []
ndcg_cpt_list = []
overall_ndcg_list = []
examples = []

# Ensure embeddings are NumPy arrays
icd_embeddings = [np.array(e) for e in icd_embeddings]
cpt_embeddings = [np.array(e) for e in cpt_embeddings]

print(f"Starting evaluation for {len(first_5_summaries)} summaries...")

for idx, summary_record in enumerate(tqdm(first_5_summaries, desc="Summaries")):
    start_time = time.time()
    print(f"\n=== Processing Summary {idx + 1}/{len(first_5_summaries)} ===")

    summary_text = summary_record["discharge_summary"]
    print(f"Summary snippet: {summary_text[:100]}...")

    # --- Step 1: Compute top code indices using embeddings ---
    print("Step 1: Extracting entities and computing similarity embeddings...")
    doc = nlp(summary_text)
    entities = [ent.text for ent in doc.ents]
    print(f"Entities: {entities}")
    entity_vectors = [np.array(nlp(ent).vector) for ent in entities]

    if not entity_vectors:
        summary_vector = np.array(doc.vector)
        entity_vectors = [summary_vector]  # fallback
    else:
        summary_vector = np.mean(entity_vectors, axis=0)

    # --- ICD similarity using per-entity cosine similarity ---
    icd_sim = []
    for icd_emb in icd_embeddings:
        score = max(cosine_similarity(np.array([ent_vec]), np.array([icd_emb]))[0][0]
                    for ent_vec in entity_vectors)
        icd_sim.append(score)
    icd_sim = np.array(icd_sim)
    top_icd_idx = np.argsort(icd_sim)[-50:][::-1]

    # --- CPT similarity using per-entity cosine similarity ---
    cpt_sim = []
    for cpt_emb in cpt_embeddings:
        score = max(cosine_similarity(np.array([ent_vec]), np.array([cpt_emb]))[0][0]
                    for ent_vec in entity_vectors)
        cpt_sim.append(score)
    cpt_sim = np.array(cpt_sim)
    top_cpt_idx = np.argsort(cpt_sim)[-50:][::-1]

    # --- Optional: print top codes like before ---
    print("\nTop ICD matches (retrieved):")
    print(icd_df_clean.iloc[top_icd_idx][["code", "description"]].head(30))

    print("\nTop CPT matches (retrieved):")
    print(cpt_df_clean.iloc[top_cpt_idx][["code", "description"]].head(30))

    # --- Step 2: Generate justifications ---
    print("Step 2: Generating justifications (this might take time)...")
    just_start = time.time()
    justifications = generate_one_line_justifications_batched( # <--- RENAMED
    summary_text, icd_df_clean, cpt_df_clean, top_icd_idx, top_cpt_idx,N_icd=15,N_cpt=15 
)
    print(f"Justifications generated in {time.time() - just_start:.2f}s")

    # --- Step 3: Compute similarity JSON ---
    print("Step 3: Computing similarity JSON (embedding comparison)...")
    sim_start = time.time()
    similarity_json = compute_similarity_json(summary_text, justifications, model, tokenizer)
    print(f"Similarity computed in {time.time() - sim_start:.2f}s")

    # --- Step 4: Compute pseudo-NDCG ---
    print("Step 4: Computing NDCG scores...")
    ndcg_start = time.time()
    ndcg_scores = compute_pseudo_ndcg_fixed(similarity_json, top_n=10)
    print(f"NDCG computed in {time.time() - ndcg_start:.2f}s")

    ndcg_icd_list.append(ndcg_scores["ndcg_icd"])
    ndcg_cpt_list.append(ndcg_scores["ndcg_cpt"])
    overall_ndcg_list.append(ndcg_scores["overall_ndcg"])

    examples.append({
        "summary": summary_text,
        "top_icd": list(similarity_json["ICD"].items())[:10],
        "top_cpt": list(similarity_json["CPT"].items())[:10],
        "ndcg": ndcg_scores
    })

    total_elapsed = time.time() - start_time
    print(f"✅ Completed summary {idx + 1}/{len(first_5_summaries)} in {total_elapsed:.2f}s")
    print(f"NDCG: {ndcg_scores}")

# --- Step 5: Aggregate results ---
results = {
    "mean_ndcg_icd": float(np.mean(ndcg_icd_list)),
    "std_ndcg_icd": float(np.std(ndcg_icd_list)),
    "mean_ndcg_cpt": float(np.mean(ndcg_cpt_list)),
    "std_overall_ndcg": float(np.std(overall_ndcg_list)),
    "mean_overall_ndcg": float(np.mean(overall_ndcg_list)),
    "std_ndcg_cpt": float(np.std(ndcg_cpt_list)),
    "examples": examples
}

print("\n=== Final Results ===")
print(json.dumps(results, indent=2))
# Out:
# Starting evaluation for 5 summaries...
# Summaries:   0%|                                                                                 | 0/5 [00:00<?, ?it/s]
# === Processing Summary 1/5 ===
# Summary snippet: 58-year-old male with acute chest pain diagnosed with inferior wall myocardial infarction. Underwent...
# Step 1: Extracting entities and computing similarity embeddings...
# Entities: ['male', 'acute chest pain', 'diagnosed', 'inferior wall myocardial infarction', 'coronary angioplasty', 'stent placement', 'stabilized', 'dual antiplatelet therapy']
#
# Top ICD matches (retrieved):
#           code                                        description
# 9152      I221  Subsequent ST elevation (STEMI) myocardial inf...
# 9151      I220  Subsequent ST elevation (STEMI) myocardial inf...
# 9142     I2119  ST elevation (STEMI) myocardial infarction inv...
# 9140     I2109  ST elevation (STEMI) myocardial infarction inv...
# 24053    R0789                                   Other chest pain
# 9139     I2102  ST elevation (STEMI) myocardial infarction inv...
# 9141     I2111  ST elevation (STEMI) myocardial infarction inv...
# 64828  T82855S         Stenosis of coronary artery stent, sequela
# 9138     I2101  ST elevation (STEMI) myocardial infarction inv...
# 64827  T82855D  Stenosis of coronary artery stent, subsequent ...
# 64924  T83122S  Displacement of indwelling ureteral stent, seq...
# 5617     G8912                        Acute post-thoracotomy pain
# 9143     I2121  ST elevation (STEMI) myocardial infarction inv...
# 64826  T82855A  Stenosis of coronary artery stent, initial enc...
# 9218    I25810  Atherosclerosis of coronary artery bypass graf...
# 64612  T82213S   Leakage of coronary artery bypass graft, sequela
# 9194    I25721  Atherosclerosis of autologous artery coronary ...
# 64609  T82212S  Displacement of coronary artery bypass graft, ...
# 9193    I25720  Atherosclerosis of autologous artery coronary ...
# 9195    I25722  Atherosclerosis of autologous artery coronary ...
# 9197    I25729  Atherosclerosis of autologous artery coronary ...
# 24054     R079                            Chest pain, unspecified
# 64923  T83122D  Displacement of indwelling ureteral stent, sub...
# 9165      I240  Acute coronary thrombosis not resulting in myo...
# 9189    I25711  Atherosclerosis of autologous vein coronary ar...
# 9188    I25710  Atherosclerosis of autologous vein coronary ar...
# 9150      I21B  Myocardial infarction with coronary microvascu...
# 9190    I25712  Atherosclerosis of autologous vein coronary ar...
# 9192    I25719  Atherosclerosis of autologous vein coronary ar...
# 9196    I25728  Atherosclerosis of autologous artery coronary ...
#
# Top CPT matches (retrieved):
#         code                   description
# 10618  43212  Esophagoscop stent placement
# 10115  37234  Revsc opn/prq tib/pero stent
# 10667  43274     Ercp duct stent placement
# 10664  43266    Egd endoscopic stent place
# 9506   33572  Open coronary endarterectomy
# 10263  4008F  Beta-blocker therapy rxd/tkn
# 11592  52282      Cystoscopy implant stent
# 5104   S1091     Stent non-coronary propel
# 9189   32110          Explore/repair chest
# 11025  4561F   Pt w/ coronary artery stent
# 10669  43276  Ercp stent exchange w/dilate
# 10265  4011F  Oral antiplatelet therapy rx
# 10063  36861            Cannula declotting
# 17284  92929   Prq card stent w/angio addl
# 12301  61630      Intracranial angioplasty
# 9476   33504         Coronary artery graft
# 9475   33503         Coronary artery graft
# 17487  93456   R hrt coronary artery angio
# 17486  93456   R hrt coronary artery angio
# 17485  93456   R hrt coronary artery angio
# 1341   D5982                Surgical stent
# 9497   33530   Coronary artery bypass/reop
# 17161  92508        Speech/hearing therapy
# 10095  37213   Thromblytic art/ven therapy
# 10264  4010F     Ace/arb therapy rxd/taken
# 17160  92507        Speech/hearing therapy
# 11038  46020            Placement of seton
# 6793   1125F    Amnt pain noted pain prsnt
# 17479  93454     Coronary artery angio s&i
# 17480  93454     Coronary artery angio s&i
# Step 2: Generating justifications (this might take time)...
# Generating 30 justifications in one batch...
# C:\Users\DigiCoffer Admin\anaconda3\Lib\site-packages\transformers\generation\configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Batch generation complete in 5932.75s
# Justifications generated in 5932.76s
# Step 3: Computing similarity JSON (embedding comparison)...
# Summaries:  20%|█████████████▍                                                     | 1/5 [2:11:37<8:46:28, 7897.18s/it]
# Similarity computed in 1798.67s
# Step 4: Computing NDCG scores...
# NDCG computed in 0.00s
# ✅ Completed summary 1/5 in 7897.18s
# NDCG: {'ndcg_icd': 0.9000368282656539, 'ndcg_cpt': 0.928981499990445, 'overall_ndcg': 0.9145091641280494}
#
# === Processing Summary 2/5 ===
# Summary snippet: 72-year-old female with type 2 diabetes and dysuria found to have E. coli urinary tract infection. T...
# Step 1: Extracting entities and computing similarity embeddings...
# Entities: ['female', 'type 2 diabetes', 'dysuria', 'E. coli', 'urinary tract infection', 'Treated with', 'intravenous ceftriaxone', 'discharged', 'symptom resolution']
#
# Top ICD matches (retrieved):
#          code                                        description
# 24250    R300                                            Dysuria
# 33       A042          Enteroinvasive Escherichia coli infection
# 22967    P393                   Neonatal urinary tract infection
# 32       A041         Enterotoxigenic Escherichia coli infection
# 34       A043       Enterohemorrhagic Escherichia coli infection
# 31       A040        Enteropathogenic Escherichia coli infection
# 20570   O2412  Pre-existing type 2 diabetes mellitus, in chil...
# 20564   O2402  Pre-existing type 1 diabetes mellitus, in chil...
# 253     A4151           Sepsis due to Escherichia coli [E. coli]
# 3575    E1165  Type 2 diabetes mellitus with hyperglycemia   ...
# 3478    E1065  Type 1 diabetes mellitus with hyperglycemia   ...
# 20571   O2413  Pre-existing type 2 diabetes mellitus, in the ...
# 3578     E119  Type 2 diabetes mellitus without complications...
# 20565   O2403  Pre-existing type 1 diabetes mellitus, in the ...
# 3484    E10A2  Type 1 diabetes mellitus, presymptomatic, Stage 2
# 3481     E109  Type 1 diabetes mellitus without complications...
# 3576    E1169  Type 2 diabetes mellitus with other specified ...
# 3483    E10A1  Type 1 diabetes mellitus, presymptomatic, Stage 1
# 3479    E1069  Type 1 diabetes mellitus with other specified ...
# 3570   E11628  Type 2 diabetes mellitus with other skin compl...
# 3473   E10628  Type 1 diabetes mellitus with other skin compl...
# 3572   E11638  Type 2 diabetes mellitus with other oral compl...
# 3475   E10638  Type 1 diabetes mellitus with other oral compl...
# 22396   O8629   Other urinary tract infection following delivery
# 3577     E118  Type 2 diabetes mellitus with unspecified comp...
# 3566   E11618  Type 2 diabetes mellitus with other diabetic a...
# 3480     E108  Type 1 diabetes mellitus with unspecified comp...
# 22393   O8620  Urinary tract infection following delivery, un...
# 3571   E11630  Type 2 diabetes mellitus with periodontal dise...
# 3469   E10618  Type 1 diabetes mellitus with other diabetic a...
#
# Top CPT matches (retrieved):
#         code                   description
# 3272   J0695    Inj ceftolozane tazobactam
# 3447   J1580      Garamycin gentamicin inj
# 3282   J0712       Ceftaroline fosamil inj
# 3267   J0689  Inj cefazolin sodium, baxter
# 3266   J0688   Inj cefazolin sodium, hikma
# 4980   S0074  Injection, cefotetan disodiu
# 5096   S1016  Non-pvc intravenous administ
# 3318   J0878          Daptomycin injection
# 3535   J2020           Linezolid injection
# 3699   J3243         Tigecycline injection
# 3373   J1267           Doripenem injection
# 3390   J1335           Ertapenem injection
# 3688   J3090       Inj tedizolid phosphate
# 3689   J3095          Telavancin injection
# 3727   J3370      Vancomycin hcl injection
# 3534   J2010          Lincomycin injection
# 3528   J1956        Levofloxacin injection
# 16343  87335             E coli 0157 ag ia
# 4983   S0081  Injection, piperacillin sodi
# 3268   J0690    Cefazolin sodium injection
# 3281   J0710   Cephapirin sodium injection
# 3274   J0697  Sterile cefuroxime injection
# 3271   J0694    Cefoxitin sodium injection
# 3546   J2186  Inj., meropenem, vaborbactam
# 4976   S0032   Injection, nafcillin sodium
# 3277   J0701    Inj. cefepime hcl (baxter)
# 3292   J0737     Inj, clindamycin (baxter)
# 3561   J2280      Inj, moxifloxacin 100 mg
# 3729   J3372  Inj, vancomycin hcl (xellia)
# 3728   J3371   Inj, vancomycin hcl (mylan)
# Step 2: Generating justifications (this might take time)...
# Generating 30 justifications in one batch...
# C:\Users\DigiCoffer Admin\anaconda3\Lib\site-packages\transformers\generation\configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Batch generation complete in 4645.81s
# Justifications generated in 4645.81s
# Step 3: Computing similarity JSON (embedding comparison)...
# Summaries:  40%|██████████████████████████▊                                        | 2/5 [3:52:26<5:40:29, 6809.95s/it]
# Similarity computed in 1203.68s
# Step 4: Computing NDCG scores...
# NDCG computed in 0.00s
# ✅ Completed summary 2/5 in 6048.89s
# NDCG: {'ndcg_icd': 0.8568982846198836, 'ndcg_cpt': 0.7450808555733915, 'overall_ndcg': 0.8009895700966376}
#
# === Processing Summary 3/5 ===
# Summary snippet: 45-year-old male admitted for acute appendicitis underwent successful laparoscopic appendectomy with...
# Step 1: Extracting entities and computing similarity embeddings...
# Entities: ['male', 'admitted', 'acute appendicitis', 'laparoscopic appendectomy', 'complications']
#
# Top ICD matches (retrieved):
#           code                                        description
# 11222    K3580                     Unspecified acute appendicitis
# 11223    K3589                           Other acute appendicitis
# 11217     K353      Acute appendicitis with localized peritonitis
# 11208     K352    Acute appendicitis with generalized peritonitis
# 10560    J0511                Acute epiglottitis with obstruction
# 10559    J0510             Acute epiglottitis without obstruction
# 11662     K812     Acute cholecystitis with chronic cholecystitis
# 11660     K810                                Acute cholecystitis
# 11224   K35890  Other acute appendicitis without perforation o...
# 11209    K3520  Acute appendicitis with generalized peritoniti...
# 11213    K3521  Acute appendicitis with generalized peritoniti...
# 11225   K35891  Other acute appendicitis without perforation, ...
# 11749    K9186  Retained cholelithiasis following cholecystectomy
# 11699     K858                           Other acute pancreatitis
# 11683     K850                      Idiopathic acute pancreatitis
# 11210   K35200  Acute appendicitis with generalized peritoniti...
# 11219    K3531  Acute appendicitis with localized peritonitis ...
# 11215   K35211  Acute appendicitis with generalized peritoniti...
# 11227      K37                           Unspecified appendicitis
# 65925  T8859XS         Other complications of anesthesia, sequela
# 64165  T798XXS       Other early complications of trauma, sequela
# 11218    K3530  Acute appendicitis with localized peritonitis,...
# 11703     K859                    Acute pancreatitis, unspecified
# 11687     K851                         Biliary acute pancreatitis
# 11765    K9409                   Other complications of colostomy
# 11770    K9419                 Other complications of enterostomy
# 22368     O754  Other complications of obstetric surgery and p...
# 11214   K35210  Acute appendicitis with generalized peritoniti...
# 11211   K35201  Acute appendicitis with generalized peritoniti...
# 212      A3689                   Other diphtheritic complications
#
# Top CPT matches (retrieved):
#         code                   description
# 11172  47564  Laparo cholecystectomy/explr
# 11171  47563  Laparo cholecystectomy/graph
# 10832  44187         Lap ileo/jejuno-stomy
# 11170  47562  Laparoscopic cholecystectomy
# 10830  44180               Lap enterolysis
# 10842  44211   Lap colectomy w/proctectomy
# 12011  58545       Laparoscopic myomectomy
# 10838  44206    Lap part colectomy w/stoma
# 10837  44205    Lap colectomy part w/ileum
# 10925  44970      Laparoscopy appendectomy
# 10836  44204      Laparo partial colectomy
# 10833  44188                 Lap colostomy
# 5115   S2079           Lap esophagomyotomy
# 10834  44202               Lap enterectomy
# 11403  50546      Laparoscopic nephrectomy
# 10766  43775        Lap sleeve gastrectomy
# 11173  47570  Laparo cholecystoenterostomy
# 10672  43279            Lap myotomy heller
# 11400  50543    Laparo partial nephrectomy
# 11402  50545    Laparo radical nephrectomy
# 11570  51992        Laparo sling operation
# 10835  44203   Lap resect s/intestine addl
# 10845  44227         Lap close enterostomy
# 10831  44186               Lap jejunostomy
# 10744  43644  Lap gastric bypass/roux-en-y
# 11002  45402   Lap proctopexy w/sig resect
# 10675  43281   Lap paraesophag hern repair
# 12013  58548              Lap radical hyst
# 11401  50544       Laparoscopy pyeloplasty
# 11468  50945  Laparoscopy ureterolithotomy
# Step 2: Generating justifications (this might take time)...
# Generating 30 justifications in one batch...
# C:\Users\DigiCoffer Admin\anaconda3\Lib\site-packages\transformers\generation\configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Batch generation complete in 3439.43s
# Justifications generated in 3439.43s
# Step 3: Computing similarity JSON (embedding comparison)...
# Summaries:  60%|████████████████████████████████████████▏                          | 3/5 [5:12:17<3:16:16, 5888.40s/it]
# Similarity computed in 1241.64s
# Step 4: Computing NDCG scores...
# NDCG computed in 0.00s
# ✅ Completed summary 3/5 in 4791.75s
# NDCG: {'ndcg_icd': 0.9722501377276835, 'ndcg_cpt': 0.9083390679975236, 'overall_ndcg': 0.9402946028626036}
#
# === Processing Summary 4/5 ===
# Summary snippet: 62-year-old female with progressive shortness of breath diagnosed with congestive heart failure exac...
# Step 1: Extracting entities and computing similarity embeddings...
# Entities: ['female', 'progressive', 'breath diagnosed', 'congestive heart failure', 'exacerbation', 'Echocardiogram', 'ejection fraction']
#
# Top ICD matches (retrieved):
#          code                                        description
# 9370    I5021          Acute systolic (congestive) heart failure
# 9374    I5031         Acute diastolic (congestive) heart failure
# 9371    I5022        Chronic systolic (congestive) heart failure
# 9375    I5032       Chronic diastolic (congestive) heart failure
# 9369    I5020    Unspecified systolic (congestive) heart failure
# 9376    I5033  Acute on chronic diastolic (congestive) heart ...
# 9372    I5023  Acute on chronic systolic (congestive) heart f...
# 9373    I5030   Unspecified diastolic (congestive) heart failure
# 9386    I5082                        Biventricular heart failure
# 9115     I119   Hypertensive heart disease without heart failure
# 9114     I110      Hypertensive heart disease with heart failure
# 9378    I5041  Acute combined systolic (congestive) and diast...
# 9380    I5043  Acute on chronic combined systolic (congestive...
# 9379    I5042  Chronic combined systolic (congestive) and dia...
# 9389    I5089                                Other heart failure
# 9377    I5040  Unspecified combined systolic (congestive) and...
# 9385   I50814      Right heart failure due to left heart failure
# 10720   J4551  Severe persistent asthma with (acute) exacerba...
# 10722  J45901       Unspecified asthma with (acute) exacerbation
# 10717   J4541  Moderate persistent asthma with (acute) exacer...
# 10714   J4531   Mild persistent asthma with (acute) exacerbation
# 10711   J4521  Mild intermittent asthma with (acute) exacerba...
# 9381   I50810                   Right heart failure, unspecified
# 9382   I50811                          Acute right heart failure
# 9110    I0981                            Rheumatic heart failure
# 9387    I5083                          High output heart failure
# 9383   I50812                        Chronic right heart failure
# 10703    J441  Chronic obstructive pulmonary disease with (ac...
# 9384   I50813               Acute on chronic right heart failure
# 3039     D732                    Chronic congestive splenomegaly
#
# Top CPT matches (retrieved):
#         code                   description
# 2809   G9680   Acute care congestive heart
# 795    A9700     Echocardiography contrast
# 2296   G8451   Pt w/abn lvef inelig b-bloc
# 6743   1038F             Persistent asthma
# 9832   35400                    Angioscopy
# 15750  83987     Exhaled breath condensate
# 5803   0001F       Heart failure composite
# 113    A4267                   Male condom
# 9679   33992      Rmvl perq left heart vad
# 2295   G8450    Beta-bloc rx pt w/abn lvef
# 17508  93503   Insert/place heart catheter
# 5576   T4529  Ped size brief/diaper sm/med
# 17598  93623      Stimulation pacing heart
# 17600  93623      Stimulation pacing heart
# 17599  93623      Stimulation pacing heart
# 9682   33997     Rmvl perq right heart vad
# 9382   33261  Ablate heart dysrhythm focus
# 9375   33251  Ablate heart dysrhythm focus
# 9374   33250  Ablate heart dysrhythm focus
# 17619  93650  Ablate heart dysrhythm focus
# 9635   33945      Transplantation of heart
# 4536   Q0035              Cardiokymography
# 4534   Q0035              Cardiokymography
# 4535   Q0035              Cardiokymography
# 17470  93451              Right heart cath
# 17471  93451              Right heart cath
# 17472  93451              Right heart cath
# 17607  93640       Evaluation heart device
# 17608  93640       Evaluation heart device
# 17609  93640       Evaluation heart device
# Step 2: Generating justifications (this might take time)...
# Generating 30 justifications in one batch...
# C:\Users\DigiCoffer Admin\anaconda3\Lib\site-packages\transformers\generation\configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Batch generation complete in 3676.85s
# Justifications generated in 3676.85s
# Step 3: Computing similarity JSON (embedding comparison)...
# Summaries:  80%|█████████████████████████████████████████████████████▌             | 4/5 [6:33:46<1:31:33, 5493.62s/it]
# Similarity computed in 1067.27s
# Step 4: Computing NDCG scores...
# NDCG computed in 0.00s
# ✅ Completed summary 4/5 in 4888.43s
# NDCG: {'ndcg_icd': 0.8737369899862643, 'ndcg_cpt': 0.9826511126401619, 'overall_ndcg': 0.9281940513132131}
#
# === Processing Summary 5/5 ===
# Summary snippet: 29-year-old female with severe right lower quadrant pain diagnosed with ruptured ovarian cyst confir...
# Step 1: Extracting entities and computing similarity embeddings...
# Entities: ['female', 'right lower quadrant', 'diagnosed', 'ruptured', 'ovarian cyst', 'confirmed by', 'pelvic ultrasound']
#
# Top ICD matches (retrieved):
#          code                                        description
# 24074   R1031                          Right lower quadrant pain
# 24075   R1032                           Left lower quadrant pain
# 24069   R1011                          Right upper quadrant pain
# 24142   R1933            Right lower quadrant abdominal rigidity
# 24070   R1012                           Left upper quadrant pain
# 23486    Q501                         Developmental ovarian cyst
# 10097    I715         Thoracoabdominal aortic aneurysm, ruptured
# 24143   R1934             Left lower quadrant abdominal rigidity
# 24079  R10813          Right lower quadrant abdominal tenderness
# 10100   I7152  Paravisceral aneurysm of the thoracoabdominal ...
# 20038   N8329                                Other ovarian cysts
# 24080  R10814           Left lower quadrant abdominal tenderness
# 10087    I713                Abdominal aortic aneurysm, ruptured
# 20026    N830                           Follicular cyst of ovary
# 10098   I7150  Thoracoabdominal aortic aneurysm, ruptured, un...
# 24140   R1931            Right upper quadrant abdominal rigidity
# 20034   N8320                          Unspecified ovarian cysts
# 10099   I7151  Supraceliac aneurysm of the thoracoabdominal a...
# 10091   I7133     Infrarenal abdominal aortic aneurysm, ruptured
# 10090   I7132     Juxtarenal abdominal aortic aneurysm, ruptured
# 10089   I7131      Pararenal abdominal aortic aneurysm, ruptured
# 24077  R10811          Right upper quadrant abdominal tenderness
# 24141   R1932             Left upper quadrant abdominal rigidity
# 6032   H02832              Dermatochalasis of right lower eyelid
# 10101    I716  Thoracoabdominal aortic aneurysm, without rupture
# 24087  R10823  Right lower quadrant rebound abdominal tenderness
# 24078  R10812           Left upper quadrant abdominal tenderness
# 10088   I7130   Abdominal aortic aneurysm, ruptured, unspecified
# 19792   N6314  Unspecified lump in the right breast, lower in...
# 20028   N8301                     Follicular cyst of right ovary
#
# Top CPT matches (retrieved):
#         code                   description
# 12164  60300        Aspir/inj thyroid cyst
# 12005  58520     Repair of ruptured uterus
# 7153   19000    Puncture aspir cyst breast
# 12064  58950     Resect ovarian malignancy
# 12065  58951     Resect ovarian malignancy
# 12066  58952     Resect ovarian malignancy
# 10629  43231  Esophagoscop ultrasound exam
# 10179  38115     Repair of ruptured spleen
# 11936  57410            Pelvic examination
# 18479  99459            Pelvic examination
# 7801   24342     Repair of ruptured tendon
# 11494  51500       Removal of bladder cyst
# 12055  58805   Drainage of ovarian cyst(s)
# 12054  58800   Drainage of ovarian cyst(s)
# 9772   35103   Repair artery rupture aorta
# 9769   35092   Repair artery rupture aorta
# 9767   35082   Repair artery rupture aorta
# 11115  47015    Inject/aspirate liver cyst
# 9763   35022   Repair artery rupture chest
# 9781   35132   Repair artery rupture groin
# 7276   20662       Application halo pelvic
# 9757   35002    Repair artery rupture neck
# 11216  48500    Surgery of pancreatic cyst
# 4175   M0301   Fabric wrapping of aneurysm
# 9775   35112  Repair artery rupture spleen
# 9784   35142   Repair artery rupture thigh
# 10944  45126           Pelvic exenteration
# 9778   35122   Repair artery rupture belly
# 13464  72170          X-ray exam of pelvis
# 13468  72190          X-ray exam of pelvis
# Step 2: Generating justifications (this might take time)...
# Generating 30 justifications in one batch...
# C:\Users\DigiCoffer Admin\anaconda3\Lib\site-packages\transformers\generation\configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Batch generation complete in 4554.72s
# Justifications generated in 4554.72s
# Step 3: Computing similarity JSON (embedding comparison)...
# Summaries: 100%|█████████████████████████████████████████████████████████████████████| 5/5 [8:21:28<00:00, 6017.62s/it]
# Similarity computed in 1765.00s
# Step 4: Computing NDCG scores...
# NDCG computed in 0.00s
# ✅ Completed summary 5/5 in 6461.82s
# NDCG: {'ndcg_icd': 0.9237742271305603, 'ndcg_cpt': 0.861601276095013, 'overall_ndcg': 0.8926877516127867}
#
# === Final Results ===
# {
#   "mean_ndcg_icd": 0.9053392935460091,
#   "std_ndcg_icd": 0.04047285737252495,
#   "mean_ndcg_cpt": 0.885330762459307,
#   "std_overall_ndcg": 0.04975298941862032,
#   "mean_overall_ndcg": 0.895335028002658,
#   "std_ndcg_cpt": 0.08017374192925965,
#   "examples": [
#     {
#       "summary": "58-year-old male with acute chest pain diagnosed with inferior wall myocardial infarction. Underwent coronary angioplasty with stent placement and was stabilized on dual antiplatelet therapy.",
#       "top_icd": [
#         [
#           "I221",
#           {
#             "justification": "This patient had a subsequent inferior wall STEMI 10 days after the initial STEMI.",
#             "similarity": 0.31494140625
#           }
#         ],
#         [
#           "I220",
#           {
#             "justification": "This is a subsequent STEMI of the anterior wall, which is the territory of the left anterior descending artery. The patient had a previous STEMI of the inferior wall, which is the territory of the right coronary artery.",
#             "similarity": 0.5478515625
#           }
#         ],
#         [
#           "I2119",
#           {
#             "justification": "This code is used for myocardial infarction of inferior wall. The patient had inferior wall myocardial infarction.",
#             "similarity": 0.285400390625
#           }
#         ],
#         [
#           "I2109",
#           {
#             "justification": "This code is used for STEMI myocardial infarction involving other coronary artery of anterior wall. The patient had inferior wall myocardial infarction.",
#             "similarity": 0.36328125
#           }
#         ],
#         [
#           "R0789",
#           {
#             "justification": "This code might apply to the patient because he was diagnosed with inferior wall myocardial infarction.",
#             "similarity": 0.2425537109375
#           }
#         ],
#         [
#           "I2102",
#           {
#             "justification": "This code is used to describe a myocardial infarction involving the left anterior descending coronary artery. The patient had a left anterior descending coronary artery stent placed for an inferior wall myocardial infarction.",
#             "similarity": 0.4853515625
#           }
#         ],
#         [
#           "I2111",
#           {
#             "justification": "Patient with inferior wall myocardial infarction. Right coronary artery is the most common culprit vessel in inferior wall myocardial infarction.",
#             "similarity": 0.360107421875
#           }
#         ],
#         [
#           "T82855S",
#           {
#             "justification": "This code is used to describe the sequela of a stent stenosis, which is a complication of the patient's history of coronary angioplasty.",
#             "similarity": 0.31005859375
#           }
#         ],
#         [
#           "I2101",
#           {
#             "justification": "This code is used to describe a myocardial infarction involving the left main coronary artery. The patient had a left main coronary artery stent placed.",
#             "similarity": 0.332763671875
#           }
#         ],
#         [
#           "T82855D",
#           {
#             "justification": "This code is used to indicate a subsequent encounter for stenosis of a coronary artery stent.",
#             "similarity": 0.194580078125
#           }
#         ]
#       ],
#       "top_cpt": [
#         [
#           "43212",
#           {
#             "justification": "This code is appropriate because the patient was diagnosed with esophageal stricture and was treated with esophageal stent placement.",
#             "similarity": 0.5283203125
#           }
#         ],
#         [
#           "37234",
#           {
#             "justification": "This code is used for a procedure involving the placement of a stent in the peroneal artery.",
#             "similarity": 0.323486328125
#           }
#         ],
#         [
#           "43274",
#           {
#             "justification": "This code is used for stent placement in the duct of the pancreas. This procedure is often done in patients with pancreatic cancer to relieve symptoms of biliary obstruction.",
#             "similarity": 0.5771484375
#           }
#         ],
#         [
#           "43266",
#           {
#             "justification": "This code is used for patients who have undergone endoscopic stent placement for esophageal stricture.",
#             "similarity": 0.43798828125
#           }
#         ],
#         [
#           "33572",
#           {
#             "justification": "This code is used for patients who undergo open coronary endarterectomy, which is a surgical procedure to remove atherosclerotic plaque from a coronary artery.",
#             "similarity": 0.60888671875
#           }
#         ],
#         [
#           "4008F",
#           {
#             "justification": "This code is used to indicate that the patient is receiving beta-blocker therapy. The patient is receiving dual antiplatelet therapy for his acute coronary syndrome.",
#             "similarity": 0.60546875
#           }
#         ],
#         [
#           "52282",
#           {
#             "justification": "This code is used for cystoscopy with implantation of a stent. This procedure is used to treat ureteral obstruction.",
#             "similarity": 0.4775390625
#           }
#         ],
#         [
#           "S1091",
#           {
#             "justification": "This code is used to indicate that the stent was not placed in the coronary artery.",
#             "similarity": 0.340576171875
#           }
#         ],
#         [
#           "32110",
#           {
#             "justification": "This code is used to describe the procedure of coronary angioplasty with stent placement.",
#             "similarity": 0.327880859375
#           }
#         ],
#         [
#           "4561F",
#           {
#             "justification": "This code is used to indicate that the patient has a stent placed in the coronary artery.",
#             "similarity": 0.36328125
#           }
#         ]
#       ],
#       "ndcg": {
#         "ndcg_icd": 0.9000368282656539,
#         "ndcg_cpt": 0.928981499990445,
#         "overall_ndcg": 0.9145091641280494
#       }
#     },
#     {
#       "summary": "72-year-old female with type 2 diabetes and dysuria found to have E. coli urinary tract infection. Treated with intravenous ceftriaxone and discharged after symptom resolution.",
#       "top_icd": [
#         [
#           "R300",
#           {
#             "justification": "This code is applied because the patient has dysuria, which is a symptom of urinary tract infection.",
#             "similarity": 0.429931640625
#           }
#         ],
#         [
#           "A042",
#           {
#             "justification": "This code is used for patients with E. coli urinary tract infection.",
#             "similarity": 0.3115234375
#           }
#         ],
#         [
#           "P393",
#           {
#             "justification": "This code is applied because the patient is a neonate and has a urinary tract infection.",
#             "similarity": 0.385498046875
#           }
#         ],
#         [
#           "A041",
#           {
#             "justification": "This code is used to identify patients with E. coli urinary tract infection.",
#             "similarity": 0.310791015625
#           }
#         ],
#         [
#           "A043",
#           {
#             "justification": "This code is used to identify patients with E. coli O157:H7 infection, which is a type of enteric E. coli infection.",
#             "similarity": 0.50244140625
#           }
#         ],
#         [
#           "A040",
#           {
#             "justification": "This code is used to identify patients with E. coli urinary tract infection.",
#             "similarity": 0.310791015625
#           }
#         ],
#         [
#           "O2412",
#           {
#             "justification": "This code is applied to patients with pre-existing type 2 diabetes mellitus who are admitted for childbirth.",
#             "similarity": 0.43017578125
#           }
#         ],
#         [
#           "O2402",
#           {
#             "justification": "This code is used to indicate that the patient has pre-existing type 1 diabetes mellitus, which is a known risk factor for the development of diabetes during pregnancy.",
#             "similarity": 0.55126953125
#           }
#         ],
#         [
#           "A4151",
#           {
#             "justification": "This code applies because the patient had a urinary tract infection caused by E. coli.",
#             "similarity": 0.369140625
#           }
#         ],
#         [
#           "E1165",
#           {
#             "justification": "This code is used to classify diabetes mellitus with hyperglycemia. The patient was diagnosed with type 2 diabetes mellitus and had hyperglycemia.",
#             "similarity": 0.638671875
#           }
#         ]
#       ],
#       "top_cpt": [
#         [
#           "J0695",
#           {
#             "justification": "This code is used for patients with complicated urinary tract infections.",
#             "similarity": 0.24560546875
#           }
#         ],
#         [
#           "J1580",
#           {
#             "justification": "This code is used for patients with a urinary tract infection.",
#             "similarity": 0.2293701171875
#           }
#         ],
#         [
#           "J0712",
#           {
#             "justification": "This code is used for ceftaroline fosamil intravenous injection. The patient was treated with ceftriaxone intravenous injection.",
#             "similarity": 0.383056640625
#           }
#         ],
#         [
#           "J0689",
#           {
#             "justification": "This is a patient with a urinary tract infection. The patient is being treated with ceftriaxone. The patient is allergic to penicillin.",
#             "similarity": 0.5009765625
#           }
#         ],
#         [
#           "J0688",
#           {
#             "justification": "This is a patient with a urinary tract infection. The patient is allergic to penicillin and cephalosporins. The patient is being discharged home and will be treated with oral cefazolin.",
#             "similarity": 0.689453125
#           }
#         ],
#         [
#           "S0074",
#           {
#             "justification": "This code is used for cefotetan, which is an alternative antibiotic that could be used to treat urinary tract infections.",
#             "similarity": 0.3203125
#           }
#         ],
#         [
#           "S1016",
#           {
#             "justification": "This code is used for patients who have been treated with intravenous ceftriaxone.",
#             "similarity": 0.272705078125
#           }
#         ],
#         [
#           "J0878",
#           {
#             "justification": "This code is used for patients with complicated urinary tract infections who are not responding to other antibiotics.",
#             "similarity": 0.343017578125
#           }
#         ],
#         [
#           "J2020",
#           {
#             "justification": "This code is used for patients with complicated urinary tract infections who are intolerant or have contraindications to beta-lactam antibiotics.",
#             "similarity": 0.437744140625
#           }
#         ],
#         [
#           "J3243",
#           {
#             "justification": "This patient has a urinary tract infection caused by E. coli, which is a pathogen that is resistant to ceftriaxone. Tigecycline is an antibiotic that is effective against E. coli and is recommended for the treatment of complicated urinary tract infections.",
#             "similarity": 0.7421875
#           }
#         ]
#       ],
#       "ndcg": {
#         "ndcg_icd": 0.8568982846198836,
#         "ndcg_cpt": 0.7450808555733915,
#         "overall_ndcg": 0.8009895700966376
#       }
#     },
#     {
#       "summary": "45-year-old male admitted for acute appendicitis underwent successful laparoscopic appendectomy with no complications.",
#       "top_icd": [
#         [
#           "K3580",
#           {
#             "justification": "Acute appendicitis is the most common cause of appendectomy. The patient was diagnosed with acute appendicitis and underwent a successful laparoscopic appendectomy.",
#             "similarity": 0.69384765625
#           }
#         ],
#         [
#           "K3589",
#           {
#             "justification": "Acute appendicitis is the most common cause of acute abdominal pain in the general population. The patient underwent a laparoscopic appendectomy for acute appendicitis.",
#             "similarity": 0.69873046875
#           }
#         ],
#         [
#           "K353",
#           {
#             "justification": "This code is assigned for acute appendicitis with localized peritonitis. The patient was diagnosed with acute appendicitis and underwent laparoscopic appendectomy.",
#             "similarity": 0.65478515625
#           }
#         ],
#         [
#           "K352",
#           {
#             "justification": "This code is assigned for acute appendicitis with generalized peritonitis. The patient was diagnosed with acute appendicitis and underwent a laparoscopic appendectomy.",
#             "similarity": 0.67529296875
#           }
#         ],
#         [
#           "J0511",
#           {
#             "justification": "This code might apply to the patient because the patient was admitted for acute appendicitis and underwent a laparoscopic appendectomy.",
#             "similarity": 0.47998046875
#           }
#         ],
#         [
#           "J0510",
#           {
#             "justification": "Acute epiglottitis is an inflammation of the epiglottis, a structure at the entrance of the windpipe. The patient had acute appendicitis, which is a common cause of epiglottitis.",
#             "similarity": 0.5703125
#           }
#         ],
#         [
#           "K812",
#           {
#             "justification": "The patient had a history of cholecystitis and choledocholithiasis, and the appendicitis was associated with cholecystitis.",
#             "similarity": 0.564453125
#           }
#         ],
#         [
#           "K810",
#           {
#             "justification": "The patient had a history of cholecystolithiasis and developed acute cholecystitis.",
#             "similarity": 0.443603515625
#           }
#         ],
#         [
#           "K35890",
#           {
#             "justification": "This code is used for acute appendicitis without perforation or gangrene. The patient was diagnosed with acute appendicitis and underwent a laparoscopic appendectomy.",
#             "similarity": 0.69189453125
#           }
#         ],
#         [
#           "K3520",
#           {
#             "justification": "This code is used for acute appendicitis with generalized peritonitis, without abscess. The patient was diagnosed with acute appendicitis and underwent a laparoscopic appendectomy.",
#             "similarity": 0.73583984375
#           }
#         ]
#       ],
#       "top_cpt": [
#         [
#           "47564",
#           {
#             "justification": "This code is used for a laparoscopic cholecystectomy, which is a procedure that removes the gallbladder.",
#             "similarity": 0.434326171875
#           }
#         ],
#         [
#           "47563",
#           {
#             "justification": "This code is used for patients who underwent laparoscopic cholecystectomy. The patient was admitted for acute appendicitis and underwent laparoscopic appendectomy.",
#             "similarity": 0.79345703125
#           }
#         ],
#         [
#           "44187",
#           {
#             "justification": "This code is used for a laparoscopic ileo/jejuno-stomy, which is a procedure that is often performed during the laparoscopic removal of the appendix.",
#             "similarity": 0.591796875
#           }
#         ],
#         [
#           "47562",
#           {
#             "justification": "This code is for a laparoscopic cholecystectomy, which is a procedure that removes the gallbladder. The patient had a laparoscopic cholecystectomy.",
#             "similarity": 0.64453125
#           }
#         ],
#         [
#           "44180",
#           {
#             "justification": "This code is used for a laparoscopic appendectomy. The patient had a laparoscopic appendectomy.",
#             "similarity": 0.470703125
#           }
#         ],
#         [
#           "44211",
#           {
#             "justification": "This code is for a laparoscopic colectomy with proctectomy. This procedure is performed when the entire colon is removed and the rectum is removed.",
#             "similarity": 0.484130859375
#           }
#         ],
#         [
#           "58545",
#           {
#             "justification": "This code is appropriate because the patient had a laparoscopic myomectomy performed.",
#             "similarity": 0.37158203125
#           }
#         ],
#         [
#           "44206",
#           {
#             "justification": "This code is for a laparoscopic proctocolectomy with a stoma. The patient had a laparoscopic appendectomy, but the code is for a different procedure.",
#             "similarity": 0.60986328125
#           }
#         ],
#         [
#           "44205",
#           {
#             "justification": "This code is used for a laparoscopic colectomy with ileum. The patient had a laparoscopic appendectomy.",
#             "similarity": 0.475830078125
#           }
#         ],
#         [
#           "44970",
#           {
#             "justification": "This code is used for a laparoscopic appendectomy, which is the procedure performed on this patient.",
#             "similarity": 0.365966796875
#           }
#         ]
#       ],
#       "ndcg": {
#         "ndcg_icd": 0.9722501377276835,
#         "ndcg_cpt": 0.9083390679975236,
#         "overall_ndcg": 0.9402946028626036
#       }
#     },
#     {
#       "summary": "62-year-old female with progressive shortness of breath diagnosed with congestive heart failure exacerbation. Echocardiogram performed showing ejection fraction 35%.",
#       "top_icd": [
#         [
#           "I5021",
#           {
#             "justification": "This patient has a recent diagnosis of congestive heart failure and is being admitted for an exacerbation of her symptoms.",
#             "similarity": 0.5009765625
#           }
#         ],
#         [
#           "I5031",
#           {
#             "justification": "This patient has a recent diagnosis of congestive heart failure and is being admitted for an exacerbation of her symptoms.",
#             "similarity": 0.5009765625
#           }
#         ],
#         [
#           "I5022",
#           {
#             "justification": "Patient has a history of congestive heart failure and is currently admitted for an exacerbation of her symptoms.",
#             "similarity": 0.477783203125
#           }
#         ],
#         [
#           "I5032",
#           {
#             "justification": "Patient has a history of hypertension and hyperlipidemia, and is currently on a diuretic for congestive heart failure.",
#             "similarity": 0.54248046875
#           }
#         ],
#         [
#           "I5020",
#           {
#             "justification": "This patient has a history of congestive heart failure and is currently admitted for an exacerbation of her symptoms.",
#             "similarity": 0.48779296875
#           }
#         ],
#         [
#           "I5033",
#           {
#             "justification": "This patient has a history of congestive heart failure and is now presenting with an acute exacerbation of her condition.",
#             "similarity": 0.50927734375
#           }
#         ],
#         [
#           "I5023",
#           {
#             "justification": "This is a 62-year-old female with a history of hypertension, hyperlipidemia, and diabetes mellitus type 2 who was admitted for shortness of breath and was found to have an ejection fraction of 35%.",
#             "similarity": 0.83935546875
#           }
#         ],
#         [
#           "I5030",
#           {
#             "justification": "Patient has a history of congestive heart failure and is being admitted for an exacerbation of her condition.",
#             "similarity": 0.4638671875
#           }
#         ],
#         [
#           "I5082",
#           {
#             "justification": "This patient has a history of congestive heart failure and an ejection fraction of 35% which is indicative of biventricular failure.",
#             "similarity": 0.59033203125
#           }
#         ],
#         [
#           "I119",
#           {
#             "justification": "Patient has a history of hypertension and ejection fraction of 35%.",
#             "similarity": 0.3603515625
#           }
#         ]
#       ],
#       "top_cpt": [
#         [
#           "G9680",
#           {
#             "justification": "This patient has a recent diagnosis of congestive heart failure and is now presenting with an exacerbation of her symptoms.",
#             "similarity": 0.62841796875
#           }
#         ],
#         [
#           "A9700",
#           {
#             "justification": "This code is used to report the use of contrast during echocardiography. Contrast is used to improve visualization of the endocardium and to assess for intracardiac shunts.",
#             "similarity": 0.53125
#           }
#         ],
#         [
#           "G8451",
#           {
#             "justification": "This code is used when the patient has a left ventricular ejection fraction of less than 35% and is ineligible for beta-blocker therapy.",
#             "similarity": 0.6064453125
#           }
#         ],
#         [
#           "1038F",
#           {
#             "justification": "Patient has a history of asthma and is currently admitted for congestive heart failure exacerbation.",
#             "similarity": 0.54345703125
#           }
#         ],
#         [
#           "35400",
#           {
#             "justification": "Patient with congestive heart failure exacerbation and ejection fraction 35% on echocardiogram.",
#             "similarity": 0.63525390625
#           }
#         ],
#         [
#           "83987",
#           {
#             "justification": "This code is used to evaluate the level of oxidative stress in exhaled breath condensate. Oxidative stress is a known contributor to heart failure.",
#             "similarity": 0.469482421875
#           }
#         ],
#         [
#           "0001F",
#           {
#             "justification": "This patient has a recent diagnosis of heart failure and is currently admitted for an exacerbation of symptoms.",
#             "similarity": 0.5302734375
#           }
#         ],
#         [
#           "A4267",
#           {
#             "justification": "Patient is sexually active and requested to use a condom.",
#             "similarity": 0.294189453125
#           }
#         ],
#         [
#           "33992",
#           {
#             "justification": "This code is used to describe a percutaneous removal of a left heart valve clot.",
#             "similarity": 0.30029296875
#           }
#         ],
#         [
#           "G8450",
#           {
#             "justification": "This patient has a recent ejection fraction of 35% and is on beta-blockers.",
#             "similarity": 0.50439453125
#           }
#         ]
#       ],
#       "ndcg": {
#         "ndcg_icd": 0.8737369899862643,
#         "ndcg_cpt": 0.9826511126401619,
#         "overall_ndcg": 0.9281940513132131
#       }
#     },
#     {
#       "summary": "29-year-old female with severe right lower quadrant pain diagnosed with ruptured ovarian cyst confirmed by pelvic ultrasound.",
#       "top_icd": [
#         [
#           "R1031",
#           {
#             "justification": "This code is used for patients with right lower quadrant pain that is not caused by a urinary tract infection.",
#             "similarity": 0.25830078125
#           }
#         ],
#         [
#           "R1032",
#           {
#             "justification": "This code is used for patients with left lower quadrant pain. The patient has left lower quadrant pain.",
#             "similarity": 0.24267578125
#           }
#         ],
#         [
#           "R1011",
#           {
#             "justification": "This code is used for patients with right upper quadrant pain that is not caused by gallstones.",
#             "similarity": 0.2337646484375
#           }
#         ],
#         [
#           "R1933",
#           {
#             "justification": "This code is used to describe a patient with severe right lower quadrant pain and pelvic ultrasound confirmed ruptured ovarian cyst.",
#             "similarity": 0.327392578125
#           }
#         ],
#         [
#           "R1012",
#           {
#             "justification": "This code is used for patients with left upper quadrant pain. The patient has a history of left upper quadrant pain.",
#             "similarity": 0.2861328125
#           }
#         ],
#         [
#           "Q501",
#           {
#             "justification": "This code is assigned to a 29-year-old female with a pelvic ultrasound confirming a ruptured ovarian cyst.",
#             "similarity": 0.305419921875
#           }
#         ],
#         [
#           "I715",
#           {
#             "justification": "This code is used for a ruptured ovarian cyst. The patient has a pelvic ultrasound confirming a ruptured ovarian cyst.",
#             "similarity": 0.341796875
#           }
#         ],
#         [
#           "R1934",
#           {
#             "justification": "This code is used for patients with severe right lower quadrant pain and pelvic ultrasound confirmed ruptured ovarian cyst.",
#             "similarity": 0.302978515625
#           }
#         ],
#         [
#           "R10813",
#           {
#             "justification": "This code is used to describe the patient\u2019s symptoms of severe right lower quadrant pain.",
#             "similarity": 0.2181396484375
#           }
#         ],
#         [
#           "I7152",
#           {
#             "justification": "This code is used for a ruptured ovarian cyst. The patient has a ruptured ovarian cyst.",
#             "similarity": 0.26806640625
#           }
#         ]
#       ],
#       "top_cpt": [
#         [
#           "60300",
#           {
#             "justification": "This code is assigned to patients with a thyroid cyst that has been aspirated and injured.",
#             "similarity": 0.281005859375
#           }
#         ],
#         [
#           "58520",
#           {
#             "justification": "This code is used for repair of a ruptured uterus. The patient has a ruptured ovarian cyst, which can cause bleeding into the peritoneal cavity and can cause uterine rupture.",
#             "similarity": 0.66748046875
#           }
#         ],
#         [
#           "19000",
#           {
#             "justification": "This code is used for a procedure to remove fluid from a cyst in the breast.",
#             "similarity": 0.2384033203125
#           }
#         ],
#         [
#           "58950",
#           {
#             "justification": "This code is used for resection of an ovarian malignancy. The patient has a ruptured ovarian cyst that is likely malignant.",
#             "similarity": 0.50634765625
#           }
#         ],
#         [
#           "58951",
#           {
#             "justification": "This code is used for resection of an ovarian malignancy. The patient has a ruptured ovarian cyst that is likely malignant.",
#             "similarity": 0.50634765625
#           }
#         ],
#         [
#           "58952",
#           {
#             "justification": "This code is used for resection of an ovarian malignancy. The patient has a ruptured ovarian cyst that is likely malignant.",
#             "similarity": 0.50634765625
#           }
#         ],
#         [
#           "43231",
#           {
#             "justification": "This code is used for an ultrasound of the esophagus, which is often done in conjunction with an ultrasound of the abdomen.",
#             "similarity": 0.41943359375
#           }
#         ],
#         [
#           "38115",
#           {
#             "justification": "The patient has a history of splenic rupture.",
#             "similarity": 0.264404296875
#           }
#         ],
#         [
#           "57410",
#           {
#             "justification": "Pelvic examination was performed to evaluate the patient's severe right lower quadrant pain.",
#             "similarity": 0.3818359375
#           }
#         ],
#         [
#           "99459",
#           {
#             "justification": "Patient presented with severe right lower quadrant pain. Pelvic examination was performed to assess the cause of the pain.",
#             "similarity": 0.49609375
#           }
#         ]
#       ],
#       "ndcg": {
#         "ndcg_icd": 0.9237742271305603,
#         "ndcg_cpt": 0.861601276095013,
#         "overall_ndcg": 0.8926877516127867
#       }
#     }
#   ]
# }

# %%
|
